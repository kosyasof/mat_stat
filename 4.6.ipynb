# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\mu_3(x^-) = E((x^- + E(x^-))^3)$

# %%
from sympy import *
a, b, n = symbols('x^{-},E(x^{-}),n')

# %%
x, y = symbols('x, E(x)')
expand((x+y)**3)
# Out:
# E(x)**3 + 3*E(x)**2*x + 3*E(x)*x**2 + x**3

# %%
expand((a+b)**3)
# Out:
# E(x^{-})**3 + 3*E(x^{-})**2*x^{-} + 3*E(x^{-})*x^{-}**2 + x^{-}**3

# %%
#1 E(E(x^-)**3) = E(x^3) = 1/n**3

# %%
a, b, c = symbols('E(X^{3}), E(X^{2}), E(X)')

# %%
k = 1/n**2 * ( a + 3*(n-1)*b*c + (n-1)*(n-2)*c**3  )
h = -3*c * 1/n**2 * ( n*b + n*(n-1)*c**2 )
g = 3*c**3
j = -c**3
factor(simplify(k+h+g+j))
# Out:
# (2*E(X)**3 - 3*E(X)*E(X^{2}) + E(X^{3}))/n**2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
h
# Out:
# -3*E(X)*(E(X)**3*n*(n - 1) + E(X^{2})*n)/n**2

# %% [markdown]
# # c)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     \

# %%
from sympy import *

# %%
x, ex, n = symbols('x, E(X), n')

# %%
mu4 = -3*a1**4 + 6*a1**2*a2 - 4*a1*a3 + a4
mu2 = a2**2 - 2*a2*a1**2 + a1**4
itog = expand(mu4/n**3 + 3*(n-1)/n**3*mu2)
itog
# Out:
# 3*E(X)**4/n**2 - 6*E(X)**4/n**3 - 6*E(X)**2*E(X^{2})/n**2 + 12*E(X)**2*E(X^{2})/n**3 - 4*E(X)*E(X^{3})/n**3 + 3*E(X^{2})**2/n**2 - 3*E(X^{2})**2/n**3 + E(X^{4})/n**3

# %%
a4, a3, a2, a1 = symbols('E(X^{4}) ,E(X^{3}), E(X^{2}), E(X)')

# %%
x1, x2, x3, x4 = symbols('x1, x2, x3, x4')

# %%
expand((x1+x2+x3+x4)**4)
# Out:
# x1**4 + 4*x1**3*x2 + 4*x1**3*x3 + 4*x1**3*x4 + 6*x1**2*x2**2 + 12*x1**2*x2*x3 + 12*x1**2*x2*x4 + 6*x1**2*x3**2 + 12*x1**2*x3*x4 + 6*x1**2*x4**2 + 4*x1*x2**3 + 12*x1*x2**2*x3 + 12*x1*x2**2*x4 + 12*x1*x2*x3**2 + 24*x1*x2*x3*x4 + 12*x1*x2*x4**2 + 4*x1*x3**3 + 12*x1*x3**2*x4 + 12*x1*x3*x4**2 + 4*x1*x4**3 + x2**4 + 4*x2**3*x3 + 4*x2**3*x4 + 6*x2**2*x3**2 + 12*x2**2*x3*x4 + 6*x2**2*x4**2 + 4*x2*x3**3 + 12*x2*x3**2*x4 + 12*x2*x3*x4**2 + 4*x2*x4**3 + x3**4 + 4*x3**3*x4 + 6*x3**2*x4**2 + 4*x3*x4**3 + x4**4

# %%
expand((x-ex)**4)
# Out:
# E(X)**4 - 4*E(X)**3*x + 6*E(X)**2*x**2 - 4*E(X)*x**3 + x**4

# %%
r1 = 1/n**3*(a4 + 4*(n-1)*a3*a1 + 3*(n-1)*a2**2 + 6*(n-1)*(n-2)*a2*a1**2 + (n-1)*(n-2)*(n-3)*a1**4)
r1
# Out:
# (E(X)**4*(n - 3)*(n - 2)*(n - 1) + E(X)**2*E(X^{2})*(n - 2)*(6*n - 6) + E(X)*E(X^{3})*(4*n - 4) + E(X^{2})**2*(3*n - 3) + E(X^{4}))/n**3

# %%
r2 = -4*a1*1/n**2*(a3+3*(n-1)*a1*a2+(n-1)*(n-2)*a1**3)
r2
# Out:
# -4*E(X)*(E(X)**3*(n - 2)*(n - 1) + E(X)*E(X^{2})*(3*n - 3) + E(X^{3}))/n**2

# %%
r3 = 6*a1**2*1/n**2*(n*a2+n*(n-1)*a1**2)
r3
# Out:
# 6*E(X)**2*(E(X)**2*n*(n - 1) + E(X^{2})*n)/n**2

# %%
r4 = -3*a1**4
r4
# Out:
# -3*E(X)**4

# %%
expand(r1+r2+r3+r4)
# Out:
# 3*E(X)**4/n**2 - 6*E(X)**4/n**3 - 6*E(X)**2*E(X^{2})/n**2 + 12*E(X)**2*E(X^{2})/n**3 - 4*E(X)*E(X^{3})/n**3 + 3*E(X^{2})**2/n**2 - 3*E(X^{2})**2/n**3 + E(X^{4})/n**3

# %% [markdown]
# ![image.png](attachment:image.png)
